# %%
# Import the dependencies 
import pandas as pd 
from citipy import citipy
import numpy as np 
import requests
from config import weather_api_key

# %%
# Create a set of random latitude and longitude 
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = list(zip(lats, lngs))

# %%
# Add the latitudes and lonitudes to a list 
coordinates = lat_lngs

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates: 
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list. 
    if city not in cities: 
        cities.append(city)
# Print the city count to comfirm sufficient count. 
len(cities)
# Out:
# 756

# %%
# Starting URL for the Weathr MAP API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc54fcfdaf604b751892f0bf5eda045f

# %%
# Create an empty list to hold the weather data. 
city_data = []
# Print the beginning of the logging. 
print("Beginning Data Retrieval   ")
print("---------------------------")

# Create counters. 
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes. 
    if (i % 50 == 0 and i > 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city. 
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city. 
    print(f"Prcessing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count. 
    record_count += 1

# Run an API request for each of the cities. 
    try:
        # Pare the JSOn and retrieve data. 
        city_weather = requests.get(city_url).json()
        # Parse out the needed data. 
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Append the city information into city_data list. 
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city. 
    except:
        print("City not found. Skipping....")
        pass
    
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ---------------------------
# Prcessing Record 1 of Set 1 | saint-philippe
# Prcessing Record 2 of Set 1 | roma
# Prcessing Record 3 of Set 1 | yeppoon
# Prcessing Record 4 of Set 1 | yumen
# Prcessing Record 5 of Set 1 | khatanga
# Prcessing Record 6 of Set 1 | ladenburg
# Prcessing Record 7 of Set 1 | port lincoln
# Prcessing Record 8 of Set 1 | arraial do cabo
# Prcessing Record 9 of Set 1 | busselton
# Prcessing Record 10 of Set 1 | amderma
# City not found. Skipping....
# Prcessing Record 11 of Set 1 | waipawa
# Prcessing Record 12 of Set 1 | liwale
# Prcessing Record 13 of Set 1 | abaete
# Prcessing Record 14 of Set 1 | hobart
# Prcessing Record 15 of Set 1 | shingu
# Prcessing Record 16 of Set 1 | constitucion
# Prcessing Record 17 of Set 1 | mataura
# Prcessing Record 18 of Set 1 | rikitea
# Prcessing Record 19 of Set 1 | gobabis
# Prcessing Record 20 of Set 1 | sobolevo
# Prcessing Record 21 of Set 1 | kodiak
# Prcessing Record 22 of Set 1 | ponta do sol
# Prcessing Record 23 of Set 1 | mkushi
# Prcessing Record 24 of Set 1 | asau
# Prcessing Record 25 of Set 1 | yellowknife
# Prcessing Record 26 of Set 1 | bluff
# Prcessing Record 27 of Set 1 | nidzica
# Prcessing Record 28 of Set 1 | saskylakh
# Prcessing Record 29 of Set 1 | vaini
# Prcessing Record 30 of Set 1 | albany
# Prcessing Record 31 of Set 1 | valdivia
# Prcessing Record 32 of Set 1 | los llanos de aridane
# Prcessing Record 33 of Set 1 | ohrid
# Prcessing Record 34 of Set 1 | provideniya
# Prcessing Record 35 of Set 1 | barrow
# Prcessing Record 36 of Set 1 | hermanus
# Prcessing Record 37 of Set 1 | belushya guba
# City not found. Skipping....
# Prcessing Record 38 of Set 1 | tasiilaq
# Prcessing Record 39 of Set 1 | valdez
# Prcessing Record 40 of Set 1 | tsihombe
# City not found. Skipping....
# Prcessing Record 41 of Set 1 | tiksi
# Prcessing Record 42 of Set 1 | khasan
# Prcessing Record 43 of Set 1 | astana
# Prcessing Record 44 of Set 1 | ushuaia
# Prcessing Record 45 of Set 1 | punta arenas
# Prcessing Record 46 of Set 1 | lolua
# City not found. Skipping....
# Prcessing Record 47 of Set 1 | mayor pablo lagerenza
# Prcessing Record 48 of Set 1 | ibra
# Prcessing Record 49 of Set 1 | bambous virieux
# Prcessing Record 50 of Set 1 | bolitoc
# Prcessing Record 51 of Set 1 | port blair
# Prcessing Record 52 of Set 1 | taolanaro
# City not found. Skipping....
# Prcessing Record 53 of Set 1 | chuy
# Prcessing Record 54 of Set 1 | mar del plata
# Prcessing Record 55 of Set 1 | pisco
# Prcessing Record 56 of Set 1 | surt
# Prcessing Record 57 of Set 1 | margasari
# Prcessing Record 58 of Set 1 | riviere-au-renard
# Prcessing Record 59 of Set 1 | alice springs
# Prcessing Record 60 of Set 1 | cape town
# Prcessing Record 61 of Set 1 | port elizabeth
# Prcessing Record 62 of Set 1 | palabuhanratu
# City not found. Skipping....
# Prcessing Record 63 of Set 1 | baykit
# Prcessing Record 64 of Set 1 | bien hoa
# Prcessing Record 65 of Set 1 | olafsvik
# Prcessing Record 66 of Set 1 | hofn
# Prcessing Record 67 of Set 1 | mandalgovi
# Prcessing Record 68 of Set 1 | koutiala
# Prcessing Record 69 of Set 1 | kapaa
# Prcessing Record 70 of Set 1 | baijiantan
# Prcessing Record 71 of Set 1 | bagan
# Prcessing Record 72 of Set 1 | ruatoria
# City not found. Skipping....
# Prcessing Record 73 of Set 1 | mahebourg
# Prcessing Record 74 of Set 1 | praia da vitoria
# Prcessing Record 75 of Set 1 | haines junction
# Prcessing Record 76 of Set 1 | iqaluit
# Prcessing Record 77 of Set 1 | nikolskoye
# Prcessing Record 78 of Set 1 | lasa
# Prcessing Record 79 of Set 1 | kaitangata
# Prcessing Record 80 of Set 1 | longlac
# City not found. Skipping....
# Prcessing Record 81 of Set 1 | victoria
# Prcessing Record 82 of Set 1 | sagae
# Prcessing Record 83 of Set 1 | mariental
# Prcessing Record 84 of Set 1 | valparaiso
# Prcessing Record 85 of Set 1 | aklavik
# Prcessing Record 86 of Set 1 | komsomolskiy
# Prcessing Record 87 of Set 1 | lebu
# Prcessing Record 88 of Set 1 | souillac
# Prcessing Record 89 of Set 1 | ambilobe
# Prcessing Record 90 of Set 1 | bethel
# Prcessing Record 91 of Set 1 | bay roberts
# Prcessing Record 92 of Set 1 | maneadero
# Prcessing Record 93 of Set 1 | tuktoyaktuk
# Prcessing Record 94 of Set 1 | thompson
# Prcessing Record 95 of Set 1 | barentsburg
# City not found. Skipping....
# Prcessing Record 96 of Set 1 | hasanpur
# Prcessing Record 97 of Set 1 | nioro
# Prcessing Record 98 of Set 1 | atuona
# Prcessing Record 99 of Set 1 | saint-augustin
# Prcessing Record 100 of Set 1 | najran
# Prcessing Record 1 of Set 2 | nizhneyansk
# City not found. Skipping....
# Prcessing Record 2 of Set 2 | launceston
# Prcessing Record 3 of Set 2 | bredasdorp
# Prcessing Record 4 of Set 2 | hithadhoo
# Prcessing Record 5 of Set 2 | oktyabrskoye
# Prcessing Record 6 of Set 2 | uyuni
# Prcessing Record 7 of Set 2 | vao
# Prcessing Record 8 of Set 2 | avarua
# Prcessing Record 9 of Set 2 | whitehorse
# Prcessing Record 10 of Set 2 | ambovombe
# Prcessing Record 11 of Set 2 | lata
# Prcessing Record 12 of Set 2 | karkaralinsk
# City not found. Skipping....
# Prcessing Record 13 of Set 2 | tongchuan
# Prcessing Record 14 of Set 2 | saint-germain-en-laye
# Prcessing Record 15 of Set 2 | jadu
# Prcessing Record 16 of Set 2 | qafsah
# City not found. Skipping....
# Prcessing Record 17 of Set 2 | at-bashi
# Prcessing Record 18 of Set 2 | ugoofaaru
# Prcessing Record 19 of Set 2 | kilindoni
# Prcessing Record 20 of Set 2 | eureka
# Prcessing Record 21 of Set 2 | faanui
# Prcessing Record 22 of Set 2 | deep river
# Prcessing Record 23 of Set 2 | puerto ayora
# Prcessing Record 24 of Set 2 | rossano
# Prcessing Record 25 of Set 2 | usinsk
# Prcessing Record 26 of Set 2 | tessalit
# Prcessing Record 27 of Set 2 | east london
# Prcessing Record 28 of Set 2 | tual
# Prcessing Record 29 of Set 2 | narsaq
# Prcessing Record 30 of Set 2 | safranbolu
# Prcessing Record 31 of Set 2 | guerrero negro
# Prcessing Record 32 of Set 2 | quibor
# Prcessing Record 33 of Set 2 | fort frances
# Prcessing Record 34 of Set 2 | hopkinsville
# Prcessing Record 35 of Set 2 | ribeira grande
# Prcessing Record 36 of Set 2 | san juan
# Prcessing Record 37 of Set 2 | snasa
# Prcessing Record 38 of Set 2 | cidreira
# Prcessing Record 39 of Set 2 | new norfolk
# Prcessing Record 40 of Set 2 | shchigry
# Prcessing Record 41 of Set 2 | mogadishu
# Prcessing Record 42 of Set 2 | vila franca do campo
# Prcessing Record 43 of Set 2 | umm lajj
# Prcessing Record 44 of Set 2 | solwezi
# Prcessing Record 45 of Set 2 | tongzi
# Prcessing Record 46 of Set 2 | babanusah
# City not found. Skipping....
# Prcessing Record 47 of Set 2 | belmonte
# Prcessing Record 48 of Set 2 | chokurdakh
# Prcessing Record 49 of Set 2 | isangel
# Prcessing Record 50 of Set 2 | nanortalik
# Prcessing Record 1 of Set 3 | aflu
# City not found. Skipping....
# Prcessing Record 2 of Set 3 | qaqortoq
# Prcessing Record 3 of Set 3 | grand river south east
# City not found. Skipping....
# Prcessing Record 4 of Set 3 | mount isa
# Prcessing Record 5 of Set 3 | san patricio
# Prcessing Record 6 of Set 3 | saleaula
# City not found. Skipping....
# Prcessing Record 7 of Set 3 | roebourne
# Prcessing Record 8 of Set 3 | hilo
# Prcessing Record 9 of Set 3 | upernavik
# Prcessing Record 10 of Set 3 | phnum penh
# City not found. Skipping....
# Prcessing Record 11 of Set 3 | illoqqortoormiut
# City not found. Skipping....
# Prcessing Record 12 of Set 3 | bitam
# Prcessing Record 13 of Set 3 | hobyo
# Prcessing Record 14 of Set 3 | pangody
# Prcessing Record 15 of Set 3 | cody
# Prcessing Record 16 of Set 3 | kuching
# Prcessing Record 17 of Set 3 | alikalia
# Prcessing Record 18 of Set 3 | jatai
# Prcessing Record 19 of Set 3 | port alfred
# Prcessing Record 20 of Set 3 | butaritari
# Prcessing Record 21 of Set 3 | saint george
# Prcessing Record 22 of Set 3 | jamestown
# Prcessing Record 23 of Set 3 | zeya
# Prcessing Record 24 of Set 3 | hami
# Prcessing Record 25 of Set 3 | yarada
# Prcessing Record 26 of Set 3 | cap malheureux
# Prcessing Record 27 of Set 3 | qaanaaq
# Prcessing Record 28 of Set 3 | vestbygda
# City not found. Skipping....
# Prcessing Record 29 of Set 3 | boissevain
# Prcessing Record 30 of Set 3 | eltham
# Prcessing Record 31 of Set 3 | boundiali
# Prcessing Record 32 of Set 3 | alice town
# Prcessing Record 33 of Set 3 | shahr-e kord
# Prcessing Record 34 of Set 3 | merauke
# Prcessing Record 35 of Set 3 | labrea
# Prcessing Record 36 of Set 3 | clyde river
# Prcessing Record 37 of Set 3 | mabaruma
# Prcessing Record 38 of Set 3 | puerto escondido
# Prcessing Record 39 of Set 3 | cartagena
# Prcessing Record 40 of Set 3 | marystown
# Prcessing Record 41 of Set 3 | yuanping
# Prcessing Record 42 of Set 3 | vaitupu
# City not found. Skipping....
# Prcessing Record 43 of Set 3 | alotau
# City not found. Skipping....
# Prcessing Record 44 of Set 3 | mindelo
# Prcessing Record 45 of Set 3 | chapais
# Prcessing Record 46 of Set 3 | kuryk
# Prcessing Record 47 of Set 3 | broken hill
# Prcessing Record 48 of Set 3 | kungur
# Prcessing Record 49 of Set 3 | kupang
# Prcessing Record 50 of Set 3 | dikson
# Prcessing Record 1 of Set 4 | pinega
# Prcessing Record 2 of Set 4 | huarmey
# Prcessing Record 3 of Set 4 | mashivka
# Prcessing Record 4 of Set 4 | san carlos de bariloche
# Prcessing Record 5 of Set 4 | moree
# Prcessing Record 6 of Set 4 | rurrenabaque
# Prcessing Record 7 of Set 4 | lubu
# Prcessing Record 8 of Set 4 | sabang
# Prcessing Record 9 of Set 4 | kavieng
# Prcessing Record 10 of Set 4 | tigil
# Prcessing Record 11 of Set 4 | carnarvon
# Prcessing Record 12 of Set 4 | pevek
# Prcessing Record 13 of Set 4 | cabrobo
# Prcessing Record 14 of Set 4 | parakou
# Prcessing Record 15 of Set 4 | lere
# Prcessing Record 16 of Set 4 | mapastepec
# Prcessing Record 17 of Set 4 | geraldton
# Prcessing Record 18 of Set 4 | arlit
# Prcessing Record 19 of Set 4 | buckingham
# Prcessing Record 20 of Set 4 | bairiki
# Prcessing Record 21 of Set 4 | vostok
# Prcessing Record 22 of Set 4 | dharchula
# Prcessing Record 23 of Set 4 | ales
# Prcessing Record 24 of Set 4 | la ronge
# Prcessing Record 25 of Set 4 | adrar
# Prcessing Record 26 of Set 4 | maragogi
# Prcessing Record 27 of Set 4 | caravelas
# Prcessing Record 28 of Set 4 | katherine
# Prcessing Record 29 of Set 4 | santo domingo
# Prcessing Record 30 of Set 4 | kargasok
# Prcessing Record 31 of Set 4 | sibolga
# Prcessing Record 32 of Set 4 | kruisfontein
# Prcessing Record 33 of Set 4 | antalaha
# Prcessing Record 34 of Set 4 | farsund
# Prcessing Record 35 of Set 4 | rancho palos verdes
# Prcessing Record 36 of Set 4 | touros
# Prcessing Record 37 of Set 4 | gat
# Prcessing Record 38 of Set 4 | castro
# Prcessing Record 39 of Set 4 | esperance
# Prcessing Record 40 of Set 4 | puerto colombia
# Prcessing Record 41 of Set 4 | manjacaze
# Prcessing Record 42 of Set 4 | yanam
# Prcessing Record 43 of Set 4 | cayenne
# Prcessing Record 44 of Set 4 | kloulklubed
# Prcessing Record 45 of Set 4 | ilulissat
# Prcessing Record 46 of Set 4 | liverpool
# Prcessing Record 47 of Set 4 | sinkat
# City not found. Skipping....
# Prcessing Record 48 of Set 4 | whitecourt
# Prcessing Record 49 of Set 4 | sangar
# Prcessing Record 50 of Set 4 | vrangel
# Prcessing Record 1 of Set 5 | yining
# Prcessing Record 2 of Set 5 | tura
# Prcessing Record 3 of Set 5 | uvinza
# Prcessing Record 4 of Set 5 | san cristobal
# Prcessing Record 5 of Set 5 | suntar
# Prcessing Record 6 of Set 5 | xinyu
# Prcessing Record 7 of Set 5 | marsh harbour
# Prcessing Record 8 of Set 5 | tucuman
# Prcessing Record 9 of Set 5 | georgetown
# Prcessing Record 10 of Set 5 | gawler
# Prcessing Record 11 of Set 5 | rawson
# Prcessing Record 12 of Set 5 | tuatapere
# Prcessing Record 13 of Set 5 | groningen
# Prcessing Record 14 of Set 5 | yar-sale
# Prcessing Record 15 of Set 5 | kasimbazar
# City not found. Skipping....
# Prcessing Record 16 of Set 5 | krasnoselkup
# Prcessing Record 17 of Set 5 | kirovsk
# Prcessing Record 18 of Set 5 | kachug
# Prcessing Record 19 of Set 5 | elat
# Prcessing Record 20 of Set 5 | la baule-escoublac
# Prcessing Record 21 of Set 5 | bolshoy uluy
# City not found. Skipping....
# Prcessing Record 22 of Set 5 | karamea
# City not found. Skipping....
# Prcessing Record 23 of Set 5 | mint hill
# Prcessing Record 24 of Set 5 | bandarbeyla
# Prcessing Record 25 of Set 5 | homer
# Prcessing Record 26 of Set 5 | capreol
# Prcessing Record 27 of Set 5 | galatini
# Prcessing Record 28 of Set 5 | coihaique
# Prcessing Record 29 of Set 5 | zhuozhou
# City not found. Skipping....
# Prcessing Record 30 of Set 5 | north battleford
# Prcessing Record 31 of Set 5 | lagoa
# Prcessing Record 32 of Set 5 | utiroa
# City not found. Skipping....
# Prcessing Record 33 of Set 5 | negotin
# Prcessing Record 34 of Set 5 | severo-kurilsk
# Prcessing Record 35 of Set 5 | kazalinsk
# City not found. Skipping....
# Prcessing Record 36 of Set 5 | ancud
# Prcessing Record 37 of Set 5 | the valley
# Prcessing Record 38 of Set 5 | townsville
# Prcessing Record 39 of Set 5 | saldanha
# Prcessing Record 40 of Set 5 | chiredzi
# Prcessing Record 41 of Set 5 | kannangad
# Prcessing Record 42 of Set 5 | san miguel
# Prcessing Record 43 of Set 5 | maskinonge
# Prcessing Record 44 of Set 5 | pauini
# Prcessing Record 45 of Set 5 | maldonado
# Prcessing Record 46 of Set 5 | kautokeino
# Prcessing Record 47 of Set 5 | mana
# Prcessing Record 48 of Set 5 | ballaghaderreen
# Prcessing Record 49 of Set 5 | kristinehamn
# Prcessing Record 50 of Set 5 | kaoma
# Prcessing Record 1 of Set 6 | kununurra
# Prcessing Record 2 of Set 6 | sorvag
# City not found. Skipping....
# Prcessing Record 3 of Set 6 | lagos
# Prcessing Record 4 of Set 6 | bengkulu
# Prcessing Record 5 of Set 6 | paradwip
# City not found. Skipping....
# Prcessing Record 6 of Set 6 | cascais
# Prcessing Record 7 of Set 6 | saint-prosper
# Prcessing Record 8 of Set 6 | kinangan
# Prcessing Record 9 of Set 6 | gorontalo
# Prcessing Record 10 of Set 6 | yanchukan
# City not found. Skipping....
# Prcessing Record 11 of Set 6 | amga
# Prcessing Record 12 of Set 6 | chumikan
# Prcessing Record 13 of Set 6 | atar
# Prcessing Record 14 of Set 6 | namatanai
# Prcessing Record 15 of Set 6 | leningradskiy
# Prcessing Record 16 of Set 6 | neubrandenburg
# Prcessing Record 17 of Set 6 | toliary
# City not found. Skipping....
# Prcessing Record 18 of Set 6 | meulaboh
# Prcessing Record 19 of Set 6 | dolbeau
# City not found. Skipping....
# Prcessing Record 20 of Set 6 | prestea
# Prcessing Record 21 of Set 6 | umzimvubu
# City not found. Skipping....
# Prcessing Record 22 of Set 6 | santa marinella
# Prcessing Record 23 of Set 6 | puteyets
# Prcessing Record 24 of Set 6 | rognan
# Prcessing Record 25 of Set 6 | gander
# Prcessing Record 26 of Set 6 | grand gaube
# Prcessing Record 27 of Set 6 | aquiraz
# Prcessing Record 28 of Set 6 | sharlyk
# Prcessing Record 29 of Set 6 | lorengau
# Prcessing Record 30 of Set 6 | magadan
# Prcessing Record 31 of Set 6 | watertown
# Prcessing Record 32 of Set 6 | phan rang
# City not found. Skipping....
# Prcessing Record 33 of Set 6 | nchelenge
# Prcessing Record 34 of Set 6 | ingham
# Prcessing Record 35 of Set 6 | anadyr
# Prcessing Record 36 of Set 6 | kirakira
# Prcessing Record 37 of Set 6 | verkhnevilyuysk
# Prcessing Record 38 of Set 6 | lemesos
# City not found. Skipping....
# Prcessing Record 39 of Set 6 | ennis
# Prcessing Record 40 of Set 6 | lamut
# Prcessing Record 41 of Set 6 | portland
# Prcessing Record 42 of Set 6 | hamilton
# Prcessing Record 43 of Set 6 | sioux lookout
# Prcessing Record 44 of Set 6 | longyearbyen
# Prcessing Record 45 of Set 6 | chicama
# Prcessing Record 46 of Set 6 | orlik
# Prcessing Record 47 of Set 6 | haicheng
# Prcessing Record 48 of Set 6 | mocambique
# City not found. Skipping....
# Prcessing Record 49 of Set 6 | sorland
# Prcessing Record 50 of Set 6 | richards bay
# Prcessing Record 1 of Set 7 | nouadhibou
# Prcessing Record 2 of Set 7 | coquimbo
# Prcessing Record 3 of Set 7 | sao filipe
# Prcessing Record 4 of Set 7 | norman wells
# Prcessing Record 5 of Set 7 | nyurba
# Prcessing Record 6 of Set 7 | oistins
# Prcessing Record 7 of Set 7 | chunskiy
# Prcessing Record 8 of Set 7 | andenes
# Prcessing Record 9 of Set 7 | manaus
# Prcessing Record 10 of Set 7 | bathsheba
# Prcessing Record 11 of Set 7 | galesong
# Prcessing Record 12 of Set 7 | orange
# Prcessing Record 13 of Set 7 | eastlake
# Prcessing Record 14 of Set 7 | sao felix do xingu
# Prcessing Record 15 of Set 7 | uthal
# Prcessing Record 16 of Set 7 | cap-aux-meules
# Prcessing Record 17 of Set 7 | sabha
# Prcessing Record 18 of Set 7 | loikaw
# Prcessing Record 19 of Set 7 | hasaki
# Prcessing Record 20 of Set 7 | payo
# Prcessing Record 21 of Set 7 | pangnirtung
# Prcessing Record 22 of Set 7 | andradas
# Prcessing Record 23 of Set 7 | attawapiskat
# City not found. Skipping....
# Prcessing Record 24 of Set 7 | wismar
# Prcessing Record 25 of Set 7 | tuy hoa
# Prcessing Record 26 of Set 7 | aniva
# Prcessing Record 27 of Set 7 | poum
# Prcessing Record 28 of Set 7 | viedma
# Prcessing Record 29 of Set 7 | ruhengeri
# Prcessing Record 30 of Set 7 | saint-francois
# Prcessing Record 31 of Set 7 | airai
# Prcessing Record 32 of Set 7 | vanimo
# Prcessing Record 33 of Set 7 | peace river
# Prcessing Record 34 of Set 7 | shitanjing
# Prcessing Record 35 of Set 7 | samusu
# City not found. Skipping....
# Prcessing Record 36 of Set 7 | cravo norte
# Prcessing Record 37 of Set 7 | vardo
# Prcessing Record 38 of Set 7 | saint-joseph
# Prcessing Record 39 of Set 7 | mount gambier
# Prcessing Record 40 of Set 7 | marcona
# City not found. Skipping....
# Prcessing Record 41 of Set 7 | teahupoo
# Prcessing Record 42 of Set 7 | codrington
# Prcessing Record 43 of Set 7 | mys shmidta
# City not found. Skipping....
# Prcessing Record 44 of Set 7 | north platte
# Prcessing Record 45 of Set 7 | luderitz
# Prcessing Record 46 of Set 7 | newton
# Prcessing Record 47 of Set 7 | broome
# Prcessing Record 48 of Set 7 | kiama
# Prcessing Record 49 of Set 7 | fortuna
# Prcessing Record 50 of Set 7 | igrim
# Prcessing Record 1 of Set 8 | swedru
# Prcessing Record 2 of Set 8 | kungurtug
# Prcessing Record 3 of Set 8 | doha
# Prcessing Record 4 of Set 8 | batticaloa
# Prcessing Record 5 of Set 8 | mikuni
# Prcessing Record 6 of Set 8 | congonhas
# Prcessing Record 7 of Set 8 | durban
# Prcessing Record 8 of Set 8 | katobu
# Prcessing Record 9 of Set 8 | saint-donat-de-montcalm
# Prcessing Record 10 of Set 8 | te anau
# Prcessing Record 11 of Set 8 | yingkou
# Prcessing Record 12 of Set 8 | mweka
# Prcessing Record 13 of Set 8 | dongli
# Prcessing Record 14 of Set 8 | niigata
# Prcessing Record 15 of Set 8 | diego de almagro
# Prcessing Record 16 of Set 8 | carutapera
# Prcessing Record 17 of Set 8 | kuito
# Prcessing Record 18 of Set 8 | tabiauea
# City not found. Skipping....
# Prcessing Record 19 of Set 8 | sijunjung
# Prcessing Record 20 of Set 8 | mvuma
# Prcessing Record 21 of Set 8 | cabra
# Prcessing Record 22 of Set 8 | djambala
# Prcessing Record 23 of Set 8 | ahipara
# Prcessing Record 24 of Set 8 | rusera
# Prcessing Record 25 of Set 8 | kurdzhinovo
# Prcessing Record 26 of Set 8 | karimganj
# Prcessing Record 27 of Set 8 | vestmanna
# Prcessing Record 28 of Set 8 | buraydah
# Prcessing Record 29 of Set 8 | kamaishi
# Prcessing Record 30 of Set 8 | amapa
# Prcessing Record 31 of Set 8 | rantepao
# Prcessing Record 32 of Set 8 | zhaotong
# Prcessing Record 33 of Set 8 | gisborne
# Prcessing Record 34 of Set 8 | port-cartier
# Prcessing Record 35 of Set 8 | takanabe
# Prcessing Record 36 of Set 8 | shimoda
# Prcessing Record 37 of Set 8 | sayyan
# Prcessing Record 38 of Set 8 | talnakh
# Prcessing Record 39 of Set 8 | kvarkeno
# Prcessing Record 40 of Set 8 | caxito
# Prcessing Record 41 of Set 8 | praia
# Prcessing Record 42 of Set 8 | fukue
# Prcessing Record 43 of Set 8 | noumea
# Prcessing Record 44 of Set 8 | korla
# Prcessing Record 45 of Set 8 | resistencia
# Prcessing Record 46 of Set 8 | serebryansk
# Prcessing Record 47 of Set 8 | sentyabrskiy
# City not found. Skipping....
# Prcessing Record 48 of Set 8 | naze
# Prcessing Record 49 of Set 8 | gilleleje
# Prcessing Record 50 of Set 8 | rudozem
# Prcessing Record 1 of Set 9 | cherskiy
# Prcessing Record 2 of Set 9 | saint-pierre
# Prcessing Record 3 of Set 9 | sawtell
# Prcessing Record 4 of Set 9 | aksarka
# Prcessing Record 5 of Set 9 | luena
# Prcessing Record 6 of Set 9 | paamiut
# Prcessing Record 7 of Set 9 | barinitas
# Prcessing Record 8 of Set 9 | timra
# Prcessing Record 9 of Set 9 | antofagasta
# Prcessing Record 10 of Set 9 | kangaba
# Prcessing Record 11 of Set 9 | manjeshwar
# Prcessing Record 12 of Set 9 | faya
# Prcessing Record 13 of Set 9 | comodoro rivadavia
# Prcessing Record 14 of Set 9 | beringovskiy
# Prcessing Record 15 of Set 9 | torbay
# Prcessing Record 16 of Set 9 | maragua
# Prcessing Record 17 of Set 9 | sile
# Prcessing Record 18 of Set 9 | freeport
# Prcessing Record 19 of Set 9 | ilo
# Prcessing Record 20 of Set 9 | flinders
# Prcessing Record 21 of Set 9 | paragominas
# Prcessing Record 22 of Set 9 | raahe
# Prcessing Record 23 of Set 9 | aksaray
# Prcessing Record 24 of Set 9 | kidal
# Prcessing Record 25 of Set 9 | plettenberg bay
# Prcessing Record 26 of Set 9 | vidim
# Prcessing Record 27 of Set 9 | novyy rogachik
# Prcessing Record 28 of Set 9 | strezhevoy
# Prcessing Record 29 of Set 9 | kijang
# Prcessing Record 30 of Set 9 | mackay
# Prcessing Record 31 of Set 9 | nandgaon
# Prcessing Record 32 of Set 9 | kribi
# Prcessing Record 33 of Set 9 | tokur
# Prcessing Record 34 of Set 9 | vuktyl
# Prcessing Record 35 of Set 9 | castle rock
# Prcessing Record 36 of Set 9 | trairi
# Prcessing Record 37 of Set 9 | urengoy
# Prcessing Record 38 of Set 9 | margate
# Prcessing Record 39 of Set 9 | mega
# Prcessing Record 40 of Set 9 | umba
# Prcessing Record 41 of Set 9 | natitingou
# Prcessing Record 42 of Set 9 | wa
# City not found. Skipping....
# Prcessing Record 43 of Set 9 | kangavar
# Prcessing Record 44 of Set 9 | lavrentiya
# Prcessing Record 45 of Set 9 | singkawang
# Prcessing Record 46 of Set 9 | fairbanks
# Prcessing Record 47 of Set 9 | glushkovo
# Prcessing Record 48 of Set 9 | tiarei
# Prcessing Record 49 of Set 9 | skibbereen
# Prcessing Record 50 of Set 9 | gulshat
# City not found. Skipping....
# Prcessing Record 1 of Set 10 | juneau
# Prcessing Record 2 of Set 10 | dawei
# Prcessing Record 3 of Set 10 | lazaro cardenas
# Prcessing Record 4 of Set 10 | dhidhdhoo
# Prcessing Record 5 of Set 10 | lake wales
# Prcessing Record 6 of Set 10 | jalu
# Prcessing Record 7 of Set 10 | clarence town
# Prcessing Record 8 of Set 10 | straumen
# Prcessing Record 9 of Set 10 | handan
# Prcessing Record 10 of Set 10 | charters towers
# Prcessing Record 11 of Set 10 | egvekinot
# Prcessing Record 12 of Set 10 | severnyy
# Prcessing Record 13 of Set 10 | grindavik
# Prcessing Record 14 of Set 10 | poretskoye
# Prcessing Record 15 of Set 10 | azimur
# City not found. Skipping....
# Prcessing Record 16 of Set 10 | louisbourg
# City not found. Skipping....
# Prcessing Record 17 of Set 10 | salinopolis
# Prcessing Record 18 of Set 10 | khonuu
# City not found. Skipping....
# Prcessing Record 19 of Set 10 | bilibino
# Prcessing Record 20 of Set 10 | urumqi
# Prcessing Record 21 of Set 10 | dhuburi
# Prcessing Record 22 of Set 10 | sao joao da barra
# Prcessing Record 23 of Set 10 | saint anthony
# Prcessing Record 24 of Set 10 | boddam
# Prcessing Record 25 of Set 10 | salalah
# Prcessing Record 26 of Set 10 | ladushkin
# Prcessing Record 27 of Set 10 | san luis
# Prcessing Record 28 of Set 10 | belyy yar
# Prcessing Record 29 of Set 10 | saquarema
# Prcessing Record 30 of Set 10 | jurilovca
# Prcessing Record 31 of Set 10 | pahalgam
# Prcessing Record 32 of Set 10 | gbarnga
# Prcessing Record 33 of Set 10 | calabozo
# Prcessing Record 34 of Set 10 | ginir
# Prcessing Record 35 of Set 10 | wawa
# Prcessing Record 36 of Set 10 | kaihua
# Prcessing Record 37 of Set 10 | cassilandia
# Prcessing Record 38 of Set 10 | leninskoye
# Prcessing Record 39 of Set 10 | burkhala
# City not found. Skipping....
# Prcessing Record 40 of Set 10 | samarai
# Prcessing Record 41 of Set 10 | bud
# Prcessing Record 42 of Set 10 | zyryanskoye
# Prcessing Record 43 of Set 10 | hervey bay
# Prcessing Record 44 of Set 10 | ulaangom
# Prcessing Record 45 of Set 10 | nova olimpia
# Prcessing Record 46 of Set 10 | rincon
# Prcessing Record 47 of Set 10 | enshi
# Prcessing Record 48 of Set 10 | talara
# Prcessing Record 49 of Set 10 | mutoko
# Prcessing Record 50 of Set 10 | sao pedro
# Prcessing Record 1 of Set 11 | sadri
# Prcessing Record 2 of Set 11 | bontang
# Prcessing Record 3 of Set 11 | hambantota
# Prcessing Record 4 of Set 11 | itacoatiara
# Prcessing Record 5 of Set 11 | kampot
# Prcessing Record 6 of Set 11 | spas-demensk
# Prcessing Record 7 of Set 11 | erenhot
# Prcessing Record 8 of Set 11 | colares
# Prcessing Record 9 of Set 11 | bugiri
# Prcessing Record 10 of Set 11 | tumannyy
# City not found. Skipping....
# Prcessing Record 11 of Set 11 | zhuhai
# Prcessing Record 12 of Set 11 | fianga
# City not found. Skipping....
# Prcessing Record 13 of Set 11 | bolungarvik
# City not found. Skipping....
# Prcessing Record 14 of Set 11 | hailey
# Prcessing Record 15 of Set 11 | podosinovets
# Prcessing Record 16 of Set 11 | pasni
# Prcessing Record 17 of Set 11 | bella union
# Prcessing Record 18 of Set 11 | rocha
# Prcessing Record 19 of Set 11 | hunza
# City not found. Skipping....
# Prcessing Record 20 of Set 11 | mahadday weyne
# City not found. Skipping....
# Prcessing Record 21 of Set 11 | drayton valley
# Prcessing Record 22 of Set 11 | beloha
# Prcessing Record 23 of Set 11 | boden
# Prcessing Record 24 of Set 11 | sitka
# Prcessing Record 25 of Set 11 | ixtapa
# Prcessing Record 26 of Set 11 | ambulu
# Prcessing Record 27 of Set 11 | kendari
# Prcessing Record 28 of Set 11 | mulege
# Prcessing Record 29 of Set 11 | avera
# Prcessing Record 30 of Set 11 | lompoc
# Prcessing Record 31 of Set 11 | desbiens
# Prcessing Record 32 of Set 11 | marfino
# Prcessing Record 33 of Set 11 | rathangan
# Prcessing Record 34 of Set 11 | shahreza
# Prcessing Record 35 of Set 11 | bolshoye sorokino
# City not found. Skipping....
# Prcessing Record 36 of Set 11 | itaituba
# Prcessing Record 37 of Set 11 | nelson bay
# Prcessing Record 38 of Set 11 | kawalu
# Prcessing Record 39 of Set 11 | aberystwyth
# Prcessing Record 40 of Set 11 | kaeo
# Prcessing Record 41 of Set 11 | kokkola
# Prcessing Record 42 of Set 11 | gboko
# Prcessing Record 43 of Set 11 | la asuncion
# Prcessing Record 44 of Set 11 | koumac
# Prcessing Record 45 of Set 11 | teguldet
# Prcessing Record 46 of Set 11 | warqla
# City not found. Skipping....
# Prcessing Record 47 of Set 11 | kolo
# Prcessing Record 48 of Set 11 | pangai
# Prcessing Record 49 of Set 11 | waingapu
# Prcessing Record 50 of Set 11 | mitsamiouli
# Prcessing Record 1 of Set 12 | palasa
# Prcessing Record 2 of Set 12 | kailua
# Prcessing Record 3 of Set 12 | evensk
# Prcessing Record 4 of Set 12 | pasighat
# Prcessing Record 5 of Set 12 | lubango
# Prcessing Record 6 of Set 12 | port-gentil
# Prcessing Record 7 of Set 12 | flin flon
# Prcessing Record 8 of Set 12 | katuli
# Prcessing Record 9 of Set 12 | baoding
# Prcessing Record 10 of Set 12 | vangaindrano
# Prcessing Record 11 of Set 12 | san quintin
# Prcessing Record 12 of Set 12 | floro
# Prcessing Record 13 of Set 12 | safwah
# City not found. Skipping....
# Prcessing Record 14 of Set 12 | scottsburgh
# City not found. Skipping....
# Prcessing Record 15 of Set 12 | dekar
# Prcessing Record 16 of Set 12 | kasangulu
# Prcessing Record 17 of Set 12 | nuuk
# Prcessing Record 18 of Set 12 | lincoln
# Prcessing Record 19 of Set 12 | catuday
# Prcessing Record 20 of Set 12 | guiratinga
# Prcessing Record 21 of Set 12 | pimentel
# Prcessing Record 22 of Set 12 | radeberg
# Prcessing Record 23 of Set 12 | neiafu
# Prcessing Record 24 of Set 12 | vestmannaeyjar
# Prcessing Record 25 of Set 12 | yilan
# Prcessing Record 26 of Set 12 | tatawin
# Prcessing Record 27 of Set 12 | tiznit
# Prcessing Record 28 of Set 12 | kizhinga
# Prcessing Record 29 of Set 12 | katsuura
# Prcessing Record 30 of Set 12 | itarema
# Prcessing Record 31 of Set 12 | sogne
# Prcessing Record 32 of Set 12 | cabo san lucas
# Prcessing Record 33 of Set 12 | cururupu
# Prcessing Record 34 of Set 12 | simao
# Prcessing Record 35 of Set 12 | muroto
# Prcessing Record 36 of Set 12 | jemnice
# Prcessing Record 37 of Set 12 | monrovia
# Prcessing Record 38 of Set 12 | vila velha
# Prcessing Record 39 of Set 12 | haapu
# City not found. Skipping....
# Prcessing Record 40 of Set 12 | san isidro
# Prcessing Record 41 of Set 12 | lesnikovo
# Prcessing Record 42 of Set 12 | kosa
# Prcessing Record 43 of Set 12 | mujiayingzi
# Prcessing Record 44 of Set 12 | havelock
# Prcessing Record 45 of Set 12 | biak
# Prcessing Record 46 of Set 12 | providencia
# Prcessing Record 47 of Set 12 | sola
# Prcessing Record 48 of Set 12 | gao
# Prcessing Record 49 of Set 12 | lac du bonnet
# Prcessing Record 50 of Set 12 | puerto del rosario
# Prcessing Record 1 of Set 13 | dragor
# Prcessing Record 2 of Set 13 | roald
# Prcessing Record 3 of Set 13 | churapcha
# Prcessing Record 4 of Set 13 | abu dhabi
# Prcessing Record 5 of Set 13 | cabedelo
# Prcessing Record 6 of Set 13 | teya
# Prcessing Record 7 of Set 13 | havre
# Prcessing Record 8 of Set 13 | mokhsogollokh
# Prcessing Record 9 of Set 13 | taman
# Prcessing Record 10 of Set 13 | mangrol
# Prcessing Record 11 of Set 13 | fort nelson
# Prcessing Record 12 of Set 13 | petropavlovsk-kamchatskiy
# Prcessing Record 13 of Set 13 | lidkoping
# Prcessing Record 14 of Set 13 | winchester
# Prcessing Record 15 of Set 13 | college
# Prcessing Record 16 of Set 13 | purpe
# Prcessing Record 17 of Set 13 | bodhan
# Prcessing Record 18 of Set 13 | humberto de campos
# Prcessing Record 19 of Set 13 | burica
# City not found. Skipping....
# Prcessing Record 20 of Set 13 | anaconda
# Prcessing Record 21 of Set 13 | karaul
# City not found. Skipping....
# Prcessing Record 22 of Set 13 | camana
# Prcessing Record 23 of Set 13 | azul
# Prcessing Record 24 of Set 13 | kamenka
# Prcessing Record 25 of Set 13 | camacha
# Prcessing Record 26 of Set 13 | cavalcante
# Prcessing Record 27 of Set 13 | moose factory
# Prcessing Record 28 of Set 13 | belaya gora
# Prcessing Record 29 of Set 13 | mwene-ditu
# Prcessing Record 30 of Set 13 | aporawan
# City not found. Skipping....
# Prcessing Record 31 of Set 13 | ochamchira
# Prcessing Record 32 of Set 13 | skjold
# Prcessing Record 33 of Set 13 | kropotkin
# Prcessing Record 34 of Set 13 | zorya
# Prcessing Record 35 of Set 13 | teknaf
# Prcessing Record 36 of Set 13 | mandurah
# Prcessing Record 37 of Set 13 | grand-santi
# Prcessing Record 38 of Set 13 | ngukurr
# City not found. Skipping....
# Prcessing Record 39 of Set 13 | maceio
# Prcessing Record 40 of Set 13 | gramoteino
# Prcessing Record 41 of Set 13 | polson
# Prcessing Record 42 of Set 13 | havre-saint-pierre
# Prcessing Record 43 of Set 13 | guarapari
# Prcessing Record 44 of Set 13 | barabash
# Prcessing Record 45 of Set 13 | vernon
# Prcessing Record 46 of Set 13 | haibowan
# City not found. Skipping....
# Prcessing Record 47 of Set 13 | praya
# Prcessing Record 48 of Set 13 | miandoab
# Prcessing Record 49 of Set 13 | alenquer
# Prcessing Record 50 of Set 13 | tautira
# Prcessing Record 1 of Set 14 | muli
# Prcessing Record 2 of Set 14 | banjar
# Prcessing Record 3 of Set 14 | tucurui
# Prcessing Record 4 of Set 14 | nalut
# Prcessing Record 5 of Set 14 | darhan
# Prcessing Record 6 of Set 14 | houston
# Prcessing Record 7 of Set 14 | luanda
# Prcessing Record 8 of Set 14 | jamame
# Prcessing Record 9 of Set 14 | uige
# Prcessing Record 10 of Set 14 | sorong
# Prcessing Record 11 of Set 14 | asosa
# Prcessing Record 12 of Set 14 | sretensk
# Prcessing Record 13 of Set 14 | flagstaff
# Prcessing Record 14 of Set 14 | dicabisagan
# Prcessing Record 15 of Set 14 | fort walton beach
# Prcessing Record 16 of Set 14 | yatou
# Prcessing Record 17 of Set 14 | mala
# Prcessing Record 18 of Set 14 | sharjah
# Prcessing Record 19 of Set 14 | malanje
# Prcessing Record 20 of Set 14 | koson
# Prcessing Record 21 of Set 14 | alta floresta
# Prcessing Record 22 of Set 14 | linfen
# Prcessing Record 23 of Set 14 | sinnamary
# Prcessing Record 24 of Set 14 | kholodnyy
# Prcessing Record 25 of Set 14 | namibe
# Prcessing Record 26 of Set 14 | xining
# Prcessing Record 27 of Set 14 | bilma
# Prcessing Record 28 of Set 14 | tsaratanana
# Prcessing Record 29 of Set 14 | bara
# Prcessing Record 30 of Set 14 | bijawar
# Prcessing Record 31 of Set 14 | emba
# Prcessing Record 32 of Set 14 | katha
# City not found. Skipping....
# Prcessing Record 33 of Set 14 | meadow lake
# Prcessing Record 34 of Set 14 | camaqua
# Prcessing Record 35 of Set 14 | nabire
# Prcessing Record 36 of Set 14 | krasnoborsk
# Prcessing Record 37 of Set 14 | xudat
# Prcessing Record 38 of Set 14 | prince rupert
# Prcessing Record 39 of Set 14 | kalevala
# Prcessing Record 40 of Set 14 | araouane
# Prcessing Record 41 of Set 14 | dickinson
# Prcessing Record 42 of Set 14 | laiwu
# Prcessing Record 43 of Set 14 | biltine
# Prcessing Record 44 of Set 14 | kahului
# Prcessing Record 45 of Set 14 | srednekolymsk
# Prcessing Record 46 of Set 14 | guadalupe victoria
# Prcessing Record 47 of Set 14 | rio gallegos
# Prcessing Record 48 of Set 14 | imeni vorovskogo
# Prcessing Record 49 of Set 14 | kakonko
# Prcessing Record 50 of Set 14 | progreso
# Prcessing Record 1 of Set 15 | altay
# Prcessing Record 2 of Set 15 | sochaczew
# Prcessing Record 3 of Set 15 | aksu
# Prcessing Record 4 of Set 15 | makakilo city
# Prcessing Record 5 of Set 15 | napoleon
# Prcessing Record 6 of Set 15 | ostrovnoy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Creating the city data dataframe
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0   Saint-Philippe      RE -21.36   55.77     71.60        73          20
# 1             Roma      US  43.21  -75.46     80.01        74           1
# 2          Yeppoon      AU -23.13  150.73     59.00        72          59
# 3            Yumen      CN  40.28   97.20     57.25        48          17
# 4         Khatanga      RU  71.97  102.50     49.78        73          82
# 5        Ladenburg      DE  49.48    8.61     69.80        46         100
# 6     Port Lincoln      AU -34.73  135.87     56.89        76          57
# 7  Arraial Do Cabo      BR -22.97  -42.03     82.40        65           0
# 8        Busselton      AU -33.65  115.33     41.00        70           5
# 9          Waipawa      NZ -41.41  175.52     55.40        76           5
#
#    Wind Speed Current Description
# 0       17.22          few clouds
# 1        6.93          light rain
# 2        8.05       broken clouds
# 3        7.23          few clouds
# 4        7.90       broken clouds
# 5        4.70     overcast clouds
# 6       16.58       broken clouds
# 7       18.34           clear sky
# 8        7.16           clear sky
# 9       17.22           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_data into a csv 
city_data_df.to_csv(output_data_file, index_label = "City_ID")
