# %%
# Import the dependencies 
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np 
from scipy.stats import linregress

# %%
# Create a set of random latitude and longitude 
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = list(zip(lats, lngs))

# %%
# Add the latitudes and lonitudes to a list 
coordinates = lat_lngs

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 583

# %%
# Import the requests library. 
import requests

# Import the API Key. 
from config import weather_api_key

from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dc54fcfdaf604b751892f0bf5eda045f

# %%
# Create an empty list to hold the weather data. 
city_data = []
 # Print the beginning of the logging. 
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list. 
for i,  in enumerate(cities):
    
    # Group cities in sets of 50 for logging purpoes. 
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create ednpoit URL with each city. 
    city_url = url + "&q" + city.replace("", "+")
    
    # Log the URL, record, and set numbers and the city. 
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count +=1
# Run an API request for each of the cities.
    try:
            # Parse the JSON and retrieve data.
            city_weather = requests.get(city_url).json()
            # Parse out the needed data.
            city_lat = city_weather["coord"]["lat"]
            city_lng = city_weather["coord"]["lon"]
            city_max_temp = city_weather["main"]["temp_max"]
            city_humidity = city_weather["main"]["humidity"]
            city_clouds = city_weather["clouds"]["all"]
            city_wind = city_weather["wind"]["speed"]
            city_country = city_weather["sys"]["country"]
            # Convert the date to ISO standard.
            city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
            # Append the city information into city_data list.
            city_data.append({"City": city.title(),
                              "Lat": city_lat,
                              "Lng": city_lng,
                              "Max Temp": city_max_temp,
                              "Humidity": city_humidity,
                              "Cloudiness": city_clouds,
                              "Wind Speed": city_wind,
                              "Country": city_country,
                              "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-285673a7dd50> in <module>
#      10
#      11 # Loop through all the cities in our list.
# ---> 12 for i,  in enumerate(cities):
#      13
#      14     # Group cities in sets of 50 for logging purpoes.
#
# ValueError: too many values to unpack (expected 1)

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kapaa
# Processing Record 2 of Set 1 | hasaki
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | port elizabeth
# Processing Record 5 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 6 of Set 1 | upernavik
# Processing Record 7 of Set 1 | baijiantan
# Processing Record 8 of Set 1 | beaufort
# Processing Record 9 of Set 1 | flinders
# Processing Record 10 of Set 1 | torbay
# Processing Record 11 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | la palma
# Processing Record 14 of Set 1 | qandala
# Processing Record 15 of Set 1 | bolungarvik
# City not found. Skipping...
# Processing Record 16 of Set 1 | inhambane
# Processing Record 17 of Set 1 | yellowknife
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | sitka
# Processing Record 20 of Set 1 | faanui
# Processing Record 21 of Set 1 | castro
# Processing Record 22 of Set 1 | haines junction
# Processing Record 23 of Set 1 | sao filipe
# Processing Record 24 of Set 1 | arraial do cabo
# Processing Record 25 of Set 1 | pisco
# Processing Record 26 of Set 1 | lucapa
# Processing Record 27 of Set 1 | bengkulu
# Processing Record 28 of Set 1 | camacupa
# Processing Record 29 of Set 1 | kearney
# Processing Record 30 of Set 1 | poronaysk
# Processing Record 31 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 32 of Set 1 | bang saphan
# Processing Record 33 of Set 1 | sarkand
# Processing Record 34 of Set 1 | albany
# Processing Record 35 of Set 1 | barrow
# Processing Record 36 of Set 1 | hermanus
# Processing Record 37 of Set 1 | ahipara
# Processing Record 38 of Set 1 | hemsedal
# Processing Record 39 of Set 1 | rawannawi
# City not found. Skipping...
# Processing Record 40 of Set 1 | pacific grove
# Processing Record 41 of Set 1 | ponta do sol
# Processing Record 42 of Set 1 | merauke
# Processing Record 43 of Set 1 | asau
# Processing Record 44 of Set 1 | vaini
# Processing Record 45 of Set 1 | hamilton
# Processing Record 46 of Set 1 | lunenburg
# Processing Record 47 of Set 1 | mar del plata
# Processing Record 48 of Set 1 | clyde river
# Processing Record 49 of Set 1 | richards bay
# Processing Record 50 of Set 1 | lebu
# Processing Record 1 of Set 2 | mataura
# Processing Record 2 of Set 2 | hobart
# Processing Record 3 of Set 2 | atuona
# Processing Record 4 of Set 2 | noumea
# Processing Record 5 of Set 2 | bluff
# Processing Record 6 of Set 2 | rikitea
# Processing Record 7 of Set 2 | bathsheba
# Processing Record 8 of Set 2 | mount isa
# Processing Record 9 of Set 2 | verkhovazhye
# Processing Record 10 of Set 2 | lavrentiya
# Processing Record 11 of Set 2 | barbar
# City not found. Skipping...
# Processing Record 12 of Set 2 | meulaboh
# Processing Record 13 of Set 2 | mayumba
# Processing Record 14 of Set 2 | egvekinot
# Processing Record 15 of Set 2 | mao
# Processing Record 16 of Set 2 | namibe
# Processing Record 17 of Set 2 | houma
# Processing Record 18 of Set 2 | gazanjyk
# Processing Record 19 of Set 2 | nanortalik
# Processing Record 20 of Set 2 | nouadhibou
# Processing Record 21 of Set 2 | la plata
# Processing Record 22 of Set 2 | shingu
# Processing Record 23 of Set 2 | adrar
# Processing Record 24 of Set 2 | broome
# Processing Record 25 of Set 2 | payyannur
# Processing Record 26 of Set 2 | alizai
# Processing Record 27 of Set 2 | iqaluit
# Processing Record 28 of Set 2 | xinpu
# Processing Record 29 of Set 2 | beringovskiy
# Processing Record 30 of Set 2 | harare
# Processing Record 31 of Set 2 | buqayq
# City not found. Skipping...
# Processing Record 32 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 33 of Set 2 | la ronge
# Processing Record 34 of Set 2 | cherskiy
# Processing Record 35 of Set 2 | anadyr
# Processing Record 36 of Set 2 | east london
# Processing Record 37 of Set 2 | constitucion
# Processing Record 38 of Set 2 | batagay
# Processing Record 39 of Set 2 | nabire
# Processing Record 40 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 41 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 42 of Set 2 | norman wells
# Processing Record 43 of Set 2 | saint george
# Processing Record 44 of Set 2 | ilulissat
# Processing Record 45 of Set 2 | carnarvon
# Processing Record 46 of Set 2 | saskylakh
# Processing Record 47 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 48 of Set 2 | gigmoto
# Processing Record 49 of Set 2 | kamuli
# Processing Record 50 of Set 2 | juneau
# Processing Record 1 of Set 3 | malwan
# City not found. Skipping...
# Processing Record 2 of Set 3 | lazaro cardenas
# Processing Record 3 of Set 3 | dejen
# Processing Record 4 of Set 3 | butaritari
# Processing Record 5 of Set 3 | nawa
# Processing Record 6 of Set 3 | cuamba
# Processing Record 7 of Set 3 | tasiilaq
# Processing Record 8 of Set 3 | jamestown
# Processing Record 9 of Set 3 | provideniya
# Processing Record 10 of Set 3 | tuktoyaktuk
# Processing Record 11 of Set 3 | chokurdakh
# Processing Record 12 of Set 3 | micheweni
# Processing Record 13 of Set 3 | thompson
# Processing Record 14 of Set 3 | ruatoria
# City not found. Skipping...
# Processing Record 15 of Set 3 | macau
# Processing Record 16 of Set 3 | san patricio
# Processing Record 17 of Set 3 | chuy
# Processing Record 18 of Set 3 | fortuna
# Processing Record 19 of Set 3 | avarua
# Processing Record 20 of Set 3 | pevek
# Processing Record 21 of Set 3 | vila
# Processing Record 22 of Set 3 | popondetta
# Processing Record 23 of Set 3 | abu kamal
# Processing Record 24 of Set 3 | puerto ayora
# Processing Record 25 of Set 3 | ginda
# Processing Record 26 of Set 3 | port alfred
# Processing Record 27 of Set 3 | gorontalo
# Processing Record 28 of Set 3 | cabo san lucas
# Processing Record 29 of Set 3 | lompoc
# Processing Record 30 of Set 3 | muros
# Processing Record 31 of Set 3 | pauini
# Processing Record 32 of Set 3 | tiksi
# Processing Record 33 of Set 3 | pangai
# Processing Record 34 of Set 3 | qaanaaq
# Processing Record 35 of Set 3 | cape town
# Processing Record 36 of Set 3 | aswan
# Processing Record 37 of Set 3 | avera
# Processing Record 38 of Set 3 | belton
# Processing Record 39 of Set 3 | puerto escondido
# Processing Record 40 of Set 3 | daru
# Processing Record 41 of Set 3 | new norfolk
# Processing Record 42 of Set 3 | husavik
# Processing Record 43 of Set 3 | chibombo
# Processing Record 44 of Set 3 | nyurba
# Processing Record 45 of Set 3 | kavaratti
# Processing Record 46 of Set 3 | bredasdorp
# Processing Record 47 of Set 3 | talnakh
# Processing Record 48 of Set 3 | tessalit
# Processing Record 49 of Set 3 | kiama
# Processing Record 50 of Set 3 | portland
# Processing Record 1 of Set 4 | lima duarte
# Processing Record 2 of Set 4 | ostrovnoy
# Processing Record 3 of Set 4 | attock
# Processing Record 4 of Set 4 | romanovka
# Processing Record 5 of Set 4 | kieta
# Processing Record 6 of Set 4 | narasannapeta
# Processing Record 7 of Set 4 | kruisfontein
# Processing Record 8 of Set 4 | villa oliva
# City not found. Skipping...
# Processing Record 9 of Set 4 | cukai
# Processing Record 10 of Set 4 | carballo
# Processing Record 11 of Set 4 | farmington
# Processing Record 12 of Set 4 | kodiak
# Processing Record 13 of Set 4 | pudozh
# Processing Record 14 of Set 4 | port lincoln
# Processing Record 15 of Set 4 | araceli
# Processing Record 16 of Set 4 | naron
# Processing Record 17 of Set 4 | yarmolyntsi
# Processing Record 18 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 19 of Set 4 | yermakovskoye
# Processing Record 20 of Set 4 | tabou
# Processing Record 21 of Set 4 | airai
# Processing Record 22 of Set 4 | bethel
# Processing Record 23 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 24 of Set 4 | eldikan
# City not found. Skipping...
# Processing Record 25 of Set 4 | mocajuba
# Processing Record 26 of Set 4 | stekolnyy
# City not found. Skipping...
# Processing Record 27 of Set 4 | udomlya
# Processing Record 28 of Set 4 | salekhard
# Processing Record 29 of Set 4 | auki
# Processing Record 30 of Set 4 | hithadhoo
# Processing Record 31 of Set 4 | nong bua
# Processing Record 32 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 33 of Set 4 | kifri
# Processing Record 34 of Set 4 | tshikapa
# Processing Record 35 of Set 4 | pozo colorado
# Processing Record 36 of Set 4 | trincomalee
# Processing Record 37 of Set 4 | erenhot
# Processing Record 38 of Set 4 | saint-philippe
# Processing Record 39 of Set 4 | palu
# Processing Record 40 of Set 4 | oksfjord
# Processing Record 41 of Set 4 | krasnovishersk
# Processing Record 42 of Set 4 | lasa
# Processing Record 43 of Set 4 | alyangula
# Processing Record 44 of Set 4 | dhidhdhoo
# Processing Record 45 of Set 4 | geraldton
# Processing Record 46 of Set 4 | vila velha
# Processing Record 47 of Set 4 | mendoza
# Processing Record 48 of Set 4 | west wendover
# Processing Record 49 of Set 4 | kiunga
# Processing Record 50 of Set 4 | namatanai
# Processing Record 1 of Set 5 | khatanga
# Processing Record 2 of Set 5 | ituni
# City not found. Skipping...
# Processing Record 3 of Set 5 | coquimbo
# Processing Record 4 of Set 5 | danielskuil
# Processing Record 5 of Set 5 | georgetown
# Processing Record 6 of Set 5 | kysyl-syr
# Processing Record 7 of Set 5 | manokwari
# Processing Record 8 of Set 5 | severo-kurilsk
# Processing Record 9 of Set 5 | kaitangata
# Processing Record 10 of Set 5 | antofagasta
# Processing Record 11 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 5 | chabahar
# Processing Record 13 of Set 5 | zachagansk
# City not found. Skipping...
# Processing Record 14 of Set 5 | zhuhai
# Processing Record 15 of Set 5 | coihaique
# Processing Record 16 of Set 5 | lakatoro
# Processing Record 17 of Set 5 | ixtapa
# Processing Record 18 of Set 5 | te anau
# Processing Record 19 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 20 of Set 5 | saint-denis
# Processing Record 21 of Set 5 | nome
# Processing Record 22 of Set 5 | bambous virieux
# Processing Record 23 of Set 5 | taksimo
# Processing Record 24 of Set 5 | laguna
# Processing Record 25 of Set 5 | hofn
# Processing Record 26 of Set 5 | necochea
# Processing Record 27 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 28 of Set 5 | southbridge
# Processing Record 29 of Set 5 | saldanha
# Processing Record 30 of Set 5 | dikson
# Processing Record 31 of Set 5 | zhangye
# Processing Record 32 of Set 5 | conde
# Processing Record 33 of Set 5 | taoudenni
# Processing Record 34 of Set 5 | fort frances
# Processing Record 35 of Set 5 | hilo
# Processing Record 36 of Set 5 | skagastrond
# City not found. Skipping...
# Processing Record 37 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 38 of Set 5 | comodoro rivadavia
# Processing Record 39 of Set 5 | nikolskoye
# Processing Record 40 of Set 5 | sheridan
# Processing Record 41 of Set 5 | male
# Processing Record 42 of Set 5 | mahebourg
# Processing Record 43 of Set 5 | pervomayskiy
# Processing Record 44 of Set 5 | kundiawa
# Processing Record 45 of Set 5 | gijon
# Processing Record 46 of Set 5 | high level
# Processing Record 47 of Set 5 | sabha
# Processing Record 48 of Set 5 | chumikan
# Processing Record 49 of Set 5 | vila franca do campo
# Processing Record 50 of Set 5 | sorong
# Processing Record 1 of Set 6 | lagoa
# Processing Record 2 of Set 6 | souillac
# Processing Record 3 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 4 of Set 6 | port macquarie
# Processing Record 5 of Set 6 | margate
# Processing Record 6 of Set 6 | christchurch
# Processing Record 7 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 8 of Set 6 | ikwiriri
# Processing Record 9 of Set 6 | ribeira grande
# Processing Record 10 of Set 6 | sisimiut
# Processing Record 11 of Set 6 | sur
# Processing Record 12 of Set 6 | omboue
# Processing Record 13 of Set 6 | hirara
# Processing Record 14 of Set 6 | tabuk
# Processing Record 15 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 16 of Set 6 | atar
# Processing Record 17 of Set 6 | salalah
# Processing Record 18 of Set 6 | teya
# Processing Record 19 of Set 6 | boa vista
# Processing Record 20 of Set 6 | general pico
# Processing Record 21 of Set 6 | plesetsk
# Processing Record 22 of Set 6 | gualaquiza
# Processing Record 23 of Set 6 | reefton
# City not found. Skipping...
# Processing Record 24 of Set 6 | reims
# Processing Record 25 of Set 6 | riyadh
# Processing Record 26 of Set 6 | waitati
# Processing Record 27 of Set 6 | trinidad
# Processing Record 28 of Set 6 | rocha
# Processing Record 29 of Set 6 | goderich
# Processing Record 30 of Set 6 | shar
# Processing Record 31 of Set 6 | sirnak
# Processing Record 32 of Set 6 | nieuw amsterdam
# Processing Record 33 of Set 6 | lexington
# Processing Record 34 of Set 6 | swan hill
# Processing Record 35 of Set 6 | victoria
# Processing Record 36 of Set 6 | scunthorpe
# Processing Record 37 of Set 6 | kortkeros
# Processing Record 38 of Set 6 | hovd
# Processing Record 39 of Set 6 | rameswaram
# Processing Record 40 of Set 6 | havre-saint-pierre
# Processing Record 41 of Set 6 | tual
# Processing Record 42 of Set 6 | caravelas
# Processing Record 43 of Set 6 | sao luiz gonzaga
# Processing Record 44 of Set 6 | sayyan
# Processing Record 45 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 46 of Set 6 | mujiayingzi
# Processing Record 47 of Set 6 | wladyslawowo
# Processing Record 48 of Set 6 | uruzgan
# Processing Record 49 of Set 6 | mananjary
# Processing Record 50 of Set 6 | college
# Processing Record 1 of Set 7 | fort-shevchenko
# Processing Record 2 of Set 7 | makakilo city
# Processing Record 3 of Set 7 | robertsport
# Processing Record 4 of Set 7 | birobidzhan
# Processing Record 5 of Set 7 | dalaba
# Processing Record 6 of Set 7 | balabac
# Processing Record 7 of Set 7 | la paz
# Processing Record 8 of Set 7 | mehamn
# Processing Record 9 of Set 7 | ambilobe
# Processing Record 10 of Set 7 | bull savanna
# Processing Record 11 of Set 7 | mandalgovi
# Processing Record 12 of Set 7 | miragoane
# Processing Record 13 of Set 7 | wajir
# Processing Record 14 of Set 7 | akyab
# Processing Record 15 of Set 7 | abashiri
# Processing Record 16 of Set 7 | palotina
# Processing Record 17 of Set 7 | antalaha
# Processing Record 18 of Set 7 | savannah bight
# Processing Record 19 of Set 7 | narsaq
# Processing Record 20 of Set 7 | labutta
# City not found. Skipping...
# Processing Record 21 of Set 7 | matara
# Processing Record 22 of Set 7 | vanimo
# Processing Record 23 of Set 7 | benghazi
# Processing Record 24 of Set 7 | idritsa
# Processing Record 25 of Set 7 | luderitz
# Processing Record 26 of Set 7 | flin flon
# Processing Record 27 of Set 7 | berlevag
# Processing Record 28 of Set 7 | labuan
# Processing Record 29 of Set 7 | korem
# Processing Record 30 of Set 7 | santa isabel do rio negro
# Processing Record 31 of Set 7 | rundu
# Processing Record 32 of Set 7 | rehoboth
# Processing Record 33 of Set 7 | kokopo
# Processing Record 34 of Set 7 | kajansi
# Processing Record 35 of Set 7 | cedar city
# Processing Record 36 of Set 7 | codrington
# Processing Record 37 of Set 7 | the valley
# Processing Record 38 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 39 of Set 7 | yumen
# Processing Record 40 of Set 7 | harper
# Processing Record 41 of Set 7 | martapura
# Processing Record 42 of Set 7 | yanam
# Processing Record 43 of Set 7 | esperance
# Processing Record 44 of Set 7 | agadez
# Processing Record 45 of Set 7 | bowen
# Processing Record 46 of Set 7 | vidim
# Processing Record 47 of Set 7 | hazorasp
# Processing Record 48 of Set 7 | wewak
# Processing Record 49 of Set 7 | hanover
# Processing Record 50 of Set 7 | blytheville
# Processing Record 1 of Set 8 | paamiut
# Processing Record 2 of Set 8 | camacha
# Processing Record 3 of Set 8 | les escoumins
# Processing Record 4 of Set 8 | ust-omchug
# Processing Record 5 of Set 8 | sumbe
# Processing Record 6 of Set 8 | mafinga
# Processing Record 7 of Set 8 | rio novo do sul
# Processing Record 8 of Set 8 | farah
# Processing Record 9 of Set 8 | isangel
# Processing Record 10 of Set 8 | oriximina
# Processing Record 11 of Set 8 | mikuni
# Processing Record 12 of Set 8 | paita
# Processing Record 13 of Set 8 | dunedin
# Processing Record 14 of Set 8 | nurota
# Processing Record 15 of Set 8 | jining
# Processing Record 16 of Set 8 | durant
# Processing Record 17 of Set 8 | labuhan
# Processing Record 18 of Set 8 | seidu
# Processing Record 19 of Set 8 | misratah
# Processing Record 20 of Set 8 | lubango
# Processing Record 21 of Set 8 | kigorobya
# Processing Record 22 of Set 8 | tomatlan
# Processing Record 23 of Set 8 | kangaba
# Processing Record 24 of Set 8 | gazion
# City not found. Skipping...
# Processing Record 25 of Set 8 | fort nelson
# Processing Record 26 of Set 8 | el banco
# Processing Record 27 of Set 8 | hambantota
# Processing Record 28 of Set 8 | jingdezhen
# Processing Record 29 of Set 8 | ossipee
# Processing Record 30 of Set 8 | ndele
# Processing Record 31 of Set 8 | virginia beach
# Processing Record 32 of Set 8 | tazovskiy
# Processing Record 33 of Set 8 | pabrade
# Processing Record 34 of Set 8 | ust-tsilma
# Processing Record 35 of Set 8 | makat
# Processing Record 36 of Set 8 | asyut
# Processing Record 37 of Set 8 | liverpool
# Processing Record 38 of Set 8 | borzya
# Processing Record 39 of Set 8 | ksenyevka
# City not found. Skipping...
# Processing Record 40 of Set 8 | solnechnyy
# Processing Record 41 of Set 8 | okhotsk
# Processing Record 42 of Set 8 | ponta pora
# Processing Record 43 of Set 8 | kurilsk
# Processing Record 44 of Set 8 | padang
# Processing Record 45 of Set 8 | paramonga
# Processing Record 46 of Set 8 | soyo
# Processing Record 47 of Set 8 | mitsamiouli
# Processing Record 48 of Set 8 | quelimane
# Processing Record 49 of Set 8 | ouranopolis
# City not found. Skipping...
# Processing Record 50 of Set 8 | viedma
# Processing Record 1 of Set 9 | springdale
# Processing Record 2 of Set 9 | sola
# Processing Record 3 of Set 9 | cayenne
# Processing Record 4 of Set 9 | piacabucu
# Processing Record 5 of Set 9 | bonthe
# Processing Record 6 of Set 9 | burica
# City not found. Skipping...
# Processing Record 7 of Set 9 | verkhoyansk
# Processing Record 8 of Set 9 | quatre cocos
# Processing Record 9 of Set 9 | lorengau
# Processing Record 10 of Set 9 | porto novo
# Processing Record 11 of Set 9 | mackenzie
# Processing Record 12 of Set 9 | big rapids
# Processing Record 13 of Set 9 | khasan
# Processing Record 14 of Set 9 | huayang
# Processing Record 15 of Set 9 | tateyama
# Processing Record 16 of Set 9 | kolpny
# Processing Record 17 of Set 9 | lata
# Processing Record 18 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 19 of Set 9 | chake chake
# Processing Record 20 of Set 9 | carutapera
# Processing Record 21 of Set 9 | barawe
# City not found. Skipping...
# Processing Record 22 of Set 9 | wanning
# Processing Record 23 of Set 9 | gizo
# Processing Record 24 of Set 9 | ballina
# Processing Record 25 of Set 9 | sangar
# Processing Record 26 of Set 9 | kloulklubed
# Processing Record 27 of Set 9 | saint-pierre
# Processing Record 28 of Set 9 | hualmay
# Processing Record 29 of Set 9 | kavieng
# Processing Record 30 of Set 9 | tefe
# Processing Record 31 of Set 9 | mullaitivu
# City not found. Skipping...
# Processing Record 32 of Set 9 | sompeta
# Processing Record 33 of Set 9 | dubti
# Processing Record 34 of Set 9 | amapa
# Processing Record 35 of Set 9 | karasjok
# Processing Record 36 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 37 of Set 9 | cidreira
# Processing Record 38 of Set 9 | dibulla
# Processing Record 39 of Set 9 | taltal
# Processing Record 40 of Set 9 | goundam
# Processing Record 41 of Set 9 | karaton
# Processing Record 42 of Set 9 | kajaani
# Processing Record 43 of Set 9 | palmas
# Processing Record 44 of Set 9 | sabang
# Processing Record 45 of Set 9 | alofi
# Processing Record 46 of Set 9 | nelson bay
# Processing Record 47 of Set 9 | el wasta
# City not found. Skipping...
# Processing Record 48 of Set 9 | unidad
# Processing Record 49 of Set 9 | sapouy
# Processing Record 50 of Set 9 | marv dasht
# City not found. Skipping...
# Processing Record 1 of Set 10 | jiuquan
# Processing Record 2 of Set 10 | dubbo
# Processing Record 3 of Set 10 | ramshir
# Processing Record 4 of Set 10 | umm lajj
# Processing Record 5 of Set 10 | laiagam
# City not found. Skipping...
# Processing Record 6 of Set 10 | mareeba
# Processing Record 7 of Set 10 | zabid
# Processing Record 8 of Set 10 | selfoss
# Processing Record 9 of Set 10 | sorland
# Processing Record 10 of Set 10 | umm durman
# City not found. Skipping...
# Processing Record 11 of Set 10 | oktyabrskiy
# Processing Record 12 of Set 10 | chicama
# Processing Record 13 of Set 10 | moose factory
# Processing Record 14 of Set 10 | mineiros
# Processing Record 15 of Set 10 | lima
# Processing Record 16 of Set 10 | tarudant
# City not found. Skipping...
# Processing Record 17 of Set 10 | jalingo
# Processing Record 18 of Set 10 | iquique
# Processing Record 19 of Set 10 | kangaatsiaq
# Processing Record 20 of Set 10 | tucurui
# Processing Record 21 of Set 10 | rio gallegos
# Processing Record 22 of Set 10 | pringsewu
# Processing Record 23 of Set 10 | najran
# Processing Record 24 of Set 10 | ucluelet
# Processing Record 25 of Set 10 | miles city
# Processing Record 26 of Set 10 | selma
# Processing Record 27 of Set 10 | dzerzhinsk
# Processing Record 28 of Set 10 | pushkino
# Processing Record 29 of Set 10 | touros
# Processing Record 30 of Set 10 | jalu
# Processing Record 31 of Set 10 | derzhavinsk
# Processing Record 32 of Set 10 | itambe
# Processing Record 33 of Set 10 | san quintin
# Processing Record 34 of Set 10 | bilma
# Processing Record 35 of Set 10 | kitimat
# Processing Record 36 of Set 10 | naze
# Processing Record 37 of Set 10 | aleksandrov gay
# Processing Record 38 of Set 10 | kurumkan
# Processing Record 39 of Set 10 | saint-georges
# Processing Record 40 of Set 10 | takoradi
# Processing Record 41 of Set 10 | conakry
# Processing Record 42 of Set 10 | kamyshin
# Processing Record 43 of Set 10 | new port richey
# Processing Record 44 of Set 10 | perehonivka
# Processing Record 45 of Set 10 | kahului
# Processing Record 46 of Set 10 | faya
# Processing Record 47 of Set 10 | klaksvik
# Processing Record 48 of Set 10 | utmanzai
# Processing Record 49 of Set 10 | saint-augustin
# Processing Record 50 of Set 10 | komsomolskiy
# Processing Record 1 of Set 11 | golden gate
# Processing Record 2 of Set 11 | redmond
# Processing Record 3 of Set 11 | pervomayskoye
# Processing Record 4 of Set 11 | banning
# Processing Record 5 of Set 11 | brae
# Processing Record 6 of Set 11 | santiago del estero
# Processing Record 7 of Set 11 | zyryanka
# Processing Record 8 of Set 11 | vaitape
# Processing Record 9 of Set 11 | tukrah
# Processing Record 10 of Set 11 | aguimes
# Processing Record 11 of Set 11 | verkhnevilyuysk
# Processing Record 12 of Set 11 | halifax
# Processing Record 13 of Set 11 | paranagua
# Processing Record 14 of Set 11 | punalur
# Processing Record 15 of Set 11 | port hedland
# Processing Record 16 of Set 11 | adre
# Processing Record 17 of Set 11 | port blair
# Processing Record 18 of Set 11 | tuatapere
# Processing Record 19 of Set 11 | nuuk
# Processing Record 20 of Set 11 | luanda
# Processing Record 21 of Set 11 | jackson
# Processing Record 22 of Set 11 | chernitsyno
# Processing Record 23 of Set 11 | guiglo
# Processing Record 24 of Set 11 | honiara
# Processing Record 25 of Set 11 | linxia
# Processing Record 26 of Set 11 | bandarbeyla
# Processing Record 27 of Set 11 | akdepe
# Processing Record 28 of Set 11 | myanaung
# Processing Record 29 of Set 11 | haysville
# Processing Record 30 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 11 | bayamo
# Processing Record 32 of Set 11 | kaka
# Processing Record 33 of Set 11 | baleno
# Processing Record 34 of Set 11 | karratha
# Processing Record 35 of Set 11 | belmonte
# Processing Record 36 of Set 11 | umba
# Processing Record 37 of Set 11 | kumano
# Processing Record 38 of Set 11 | pinega
# Processing Record 39 of Set 11 | san anselmo
# Processing Record 40 of Set 11 | ormara
# Processing Record 41 of Set 11 | lugovoy
# Processing Record 42 of Set 11 | vilaka
# City not found. Skipping...
# Processing Record 43 of Set 11 | grindavik
# Processing Record 44 of Set 11 | monrovia
# Processing Record 45 of Set 11 | galesong
# Processing Record 46 of Set 11 | babanusah
# City not found. Skipping...
# Processing Record 47 of Set 11 | buala
# Processing Record 48 of Set 11 | north bend
# Processing Record 49 of Set 11 | zhezkazgan
# Processing Record 50 of Set 11 | rawson
# Processing Record 1 of Set 12 | kasempa
# Processing Record 2 of Set 12 | waipawa
# Processing Record 3 of Set 12 | yaroslavl
# Processing Record 4 of Set 12 | olutanga
# Processing Record 5 of Set 12 | strezhevoy
# Processing Record 6 of Set 12 | yaan
# Processing Record 7 of Set 12 | guarda
# Processing Record 8 of Set 12 | santa maria
# Processing Record 9 of Set 12 | stoyba
# City not found. Skipping...
# Processing Record 10 of Set 12 | san rafael
# Processing Record 11 of Set 12 | ambovombe
# Processing Record 12 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 13 of Set 12 | biak
# Processing Record 14 of Set 12 | itoman
# Processing Record 15 of Set 12 | iwanai
# Processing Record 16 of Set 12 | aix-en-provence
# Processing Record 17 of Set 12 | maragogi
# Processing Record 18 of Set 12 | walvis bay
# Processing Record 19 of Set 12 | mahwa
# Processing Record 20 of Set 12 | bocanda
# Processing Record 21 of Set 12 | homer
# Processing Record 22 of Set 12 | juigalpa
# Processing Record 23 of Set 12 | opuwo
# Processing Record 24 of Set 12 | vostok
# Processing Record 25 of Set 12 | togur
# Processing Record 26 of Set 12 | mayo
# Processing Record 27 of Set 12 | riaba
# City not found. Skipping...
# Processing Record 28 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 29 of Set 12 | zhigansk
# Processing Record 30 of Set 12 | talcahuano
# Processing Record 31 of Set 12 | caledon east
# Processing Record 32 of Set 12 | olinda
# Processing Record 33 of Set 12 | longyearbyen
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionares to a Pandas DataFrame. 
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Reordering the columns in the city data dataframe 

new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country                 Date    Lat     Lng  Max Temp  \
# 0           Kapaa      US  2020-08-28 01:21:04  22.08 -159.32     84.20
# 1          Hasaki      JP  2020-08-28 01:21:06  35.73  140.83     91.99
# 2       Busselton      AU  2020-08-28 01:21:02 -33.65  115.33     57.99
# 3  Port Elizabeth      ZA  2020-08-28 01:21:21 -33.92   25.57     59.00
# 4       Upernavik      GL  2020-08-28 01:21:02  72.79  -56.15     42.24
# 5      Baijiantan      CN  2020-08-28 01:22:16  45.63   85.18     68.68
# 6        Beaufort      MY  2020-08-28 01:22:17   5.35  115.75     80.60
# 7        Flinders      AU  2020-08-28 01:22:04 -34.58  150.86     60.01
# 8          Torbay      CA  2020-08-28 01:21:07  47.67  -52.73     57.00
# 9    Punta Arenas      CL  2020-08-28 01:16:56 -53.15  -70.92     28.40
#
#    Humidity  Cloudiness  Wind Speed
# 0        66          20       12.75
# 1        79          75        8.05
# 2        88           0        1.14
# 3        62          55       11.41
# 4        72           0        5.57
# 5        42          99       17.81
# 6        88          20        2.24
# 7        28           0       10.29
# 8        82          75       16.11
# 9        92          47       29.97

# %%
# Create the output file (CSV). 
output_data_file = "weather_data/cities.csv"
# Export the City_data into a csv 
city_data_df.to_csv(output_data_file, index_label = "City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting. 
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
import time
# Build the scatter plot for latitude vs. max temperature. 
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate other graph properties. 
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure. 
plt.savefig("weather_data/Fig1.png")

# Show plot. 
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()

# %%
# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
   # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)

# %%
# Create Northern and Southern Hemisphere DataFrames. 
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere\nfor Maximum Temperature',
                       'Max Temp',(10,40))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \nfor Maximum Temperature',
                       'Max Temp',(-50,90))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \nfor % Humidity',
                       '% Humidity',(40,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \nfor % Humidity',
                       '% Humidity',(-50,15))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \nfor % Cloudiness',
                       '% Cloudiness',(10,55))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \nfor % Cloudiness',
                       '% Cloudiness',(-50,60))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \nfor Wind Speed',
                       'Wind Speed',(40,25))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \nfor Wind Speed',
                       'Wind Speed',(-50,25))
